# %% [markdown]
# <a href="https://colab.research.google.com/github/swastik-bose007/Disease-Prediction-website-ML-project/blob/main/Disease_prediction_ML_model/Naive_Bayes_Classifier/Gaussian_Naive_Bayes_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Diease prediction using Support Vector Classifier algorithm
#
# ***This is a .ipynb file where we've implemented Support Vector Classifier algo to predict the disease based on sysmtomps from the datasets***
#
# ---
